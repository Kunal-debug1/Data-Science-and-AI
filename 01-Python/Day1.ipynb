# %% [markdown]
# # Python Learning Roadmap :
#
# 📘 1. Learn the Basics
# - Basic Syntax
#
# - Variables and Data Types
#
# - Lists, Tuples, Sets, Dictionaries
#
# - Conditionals
#
# - Type Casting, Exceptions
#
# - Functions & Built-in Functions
#
# - I'll now start with the first topic: Basic Syntax

# %% [markdown]
# # MODULES :
# A module is a file containing code written by somebody else (usually) which can be
# imported and used in our programs.

# %% [markdown]
# # TYPES OF MODULES :
#
# There are two types of modules in Python.
# 1. Built in Modules (Preinstalled in Python)
# 2. External Modules (Need to install using pip)
#
# - Some examples of built in modules are **os, random** etc.
# - Some examples of external modules are **tensorflow, flask** etc.

# %% [markdown]
# # PIP :
# Pip is the package manager for python. You can use pip to install a module on your
# system.
# pip install flask # Installs Flask Module

# %% [markdown]
# # 📝 Notes: Basic Syntax in Python
# 🧠 What is Syntax?
# - Syntax is the set of rules that define how a Python program is written and interpreted.

# %%
# Hello World in Python
print("Hello, World!")

# %%
print("Welcome to Python!")        # Simple string
print("2 + 3 =", 2 + 3)            # Combining string and expression
print("Bharti", "Wagh", sep="-")  # Custom separator

# %% [markdown]
# - print() is used to output text to the console.
#
# - No need for semicolons (;) like C/C++/Java.
#
# - Python uses indentation, not braces {}.

# %% [markdown]
# # 🔹 Indentation
# Python uses indentation to define blocks of code (like loops, functions, etc.).

# %%
#✅ Correct:

if 5 > 2:
    print("Five is greater than two!")

# %%
# ❌ Incorrect:

if 3 > 1:
print("Wrong indentation")  # This will cause an IndentationError

# %% [markdown]
# - Indentation is usually 4 spaces (or a tab).
# - Incorrect indentation = IndentationError

# %% [markdown]
# # 🔹 Comments
# - Used to explain code or disable parts of it.
#
# Single-line comment:

# %%
# This is a comment

# %% [markdown]
# - Multi-line comment (usually with triple quotes):

# %%
"""
This is a 
multi-line comment

"""

# %% [markdown]
# # 🔹 Case Sensitivity
# Python is case-sensitive.

# %%
name = "Kunal"
Name = "Gaikwad"
print(name)  # Kunal
print(Name)  # Gaikwad
# Out:
# Kunal
# Gaikwad

# %%
city = "Aurangabad"
City = "Pune"
print(city)  # Output: Aurangabad
print(City)  # Output: Pune
# Out:
# Aurangabad
# Pune

# %% [markdown]
# city and City are treated as different variables

# %% [markdown]
# # 🔹 End of Line
# No need for semicolons ;, but you can use them.

# %%
print("Hello"); print("World")
# Out:
# Hello
# World

# %% [markdown]
# # Escape sequence Character:

# %%
print("He said, \"Hello!\"")  # Escaping quotes
print('Bharti\'s book')       # Using single quote in single-quoted string
print("Line1\nLine2")         # New line
print("Tab\tSpace")           # Tab space

# %% [markdown]
# # 🧮 Operators -
# 📌 What Are Operators?
#
# Operators are special symbols in Python used to perform operations on variables and values.

# %% [markdown]
# **🔢 Basic Arithmetic Operators in Python**
# | Operator       | Symbol | Example   | Result |
# | -------------- | ------ | --------- | ------ |
# | Addition       | `+`    | `3 + 5`   | `8`    |
# | Subtraction    | `-`    | `10 - 4`  | `6`    |
# | Multiplication | `*`    | `7 * 3`   | `21`   |
# | Division       | `/`    | `16 / 4`  | `4.0`  |
# | Floor Division | `//`   | `17 // 4` | `4`    |
# | Modulus        | `%`    | `10 % 3`  | `1`    |
# | Exponentiation | `**`   | `2 ** 3`  | `8`    |

# %%
# 🧠 Mini Calculator (Using Python)

num1=float(input("Enter the first number :"))
Operator = input("Enter the operators : + , - , * , / , // , % , ** ")
num2=float(input("Enter the Second number :"))

if Operator == "+":
    print (num1 + num2)
elif Operator == "-":
    print (num1 - num2)
elif Operator == "*":
    print (num1 * num2)
elif Operator == "/":
    print (num1 / num2)
elif Operator == "//":
    print (num1 // num2)
elif Operator == "%":
    print (num1 % num2)
else :
    print (num1 ** num2)
# Out:
# Enter the first number : 10
# Enter the operators : + , - , * , / , // , % , **  +
# Enter the Second number : 56
# 66.0

# %% [markdown]
# **2. Assignment Operators**
#
# Used to assign values to variables.
# | Operator | Example  | Same as     |
# | -------- | -------- | ----------- |
# | `=`      | `x = 5`  | `x = 5`     |
# | `+=`     | `x += 3` | `x = x + 3` |
# | `-=`     | `x -= 2` | `x = x - 2` |
# | `*=`     | `x *= 4` | `x = x * 4` |
# | `/=`     | `x /= 2` | `x = x / 2` |

# %%
#Example:
x = 5
x += 2
print(x)  # 7
# Out:
# 7

# %% [markdown]
# **3. Comparison Operators**
#
# Used to compare two values.
# | Operator | Description           | Example  | Output |
# | -------- | --------------------- | -------- | ------ |
# | `==`     | Equal to              | `5 == 5` | `True` |
# | `!=`     | Not equal to          | `4 != 5` | `True` |
# | `>`      | Greater than          | `6 > 3`  | `True` |
# | `<`      | Less than             | `2 < 5`  | `True` |
# | `>=`     | Greater than or equal | `3 >= 3` | `True` |
# | `<=`     | Less than or equal    | `2 <= 3` | `True` |

# %%
#Example:
a = 10
b = 20
print(a > b)  # False
# Out:
# False

# %% [markdown]
# **4. Logical Operators**
#
# Used to combine conditional statements.
# | Operator | Description           | Example          | Output |
# | -------- | --------------------- | ---------------- | ------ |
# | `and`    | True if both are true | `True and False` | False  |
# | `or`     | True if one is true   | `True or False`  | True   |
# | `not`    | Inverts the result    | `not True`       | False  |

# %%
#Example:
a = 5
b = 10
print(a > 2 and b < 20)  # True
# Out:
# True

# %% [markdown]
# **5. Bitwise Operators**
#
# Operate on bits.
# | Operator | Description | Example  | Output |     |     |
# | -------- | ----------- | -------- | ------ | --- | --- |
# | `&`      | AND         | `5 & 3`  | `1`    |     |     |
# | \`       | \`          | OR       | \`5    | 3\` | `7` |
# | `^`      | XOR         | `5 ^ 3`  | `6`    |     |     |
# | `~`      | NOT         | `~5`     | `-6`   |     |     |
# | `<<`     | Left shift  | `5 << 1` | `10`   |     |     |
# | `>>`     | Right shift | `5 >> 1` | `2`    |     |     |

# %% [markdown]
# **6. Membership Operators**
#
# Check for membership in a sequence.
# | Operator | Example            | Output  |
# | -------- | ------------------ | ------- |
# | `in`     | `'a' in 'apple'`   | `True`  |
# | `not in` | `'x' not in 'box'` | `False` |

# %% [markdown]
# **7. Identity Operators**
#
# Check if two variables refer to the same object.
# | Operator | Example      | Output     |
# | -------- | ------------ | ---------- |
# | `is`     | `a is b`     | True/False |
# | `is not` | `a is not b` | True/False |

# %%
x = 10
y = 5

print(x + y)       # Arithmetic
print(x > y)       # Comparison
print(x == 10 and y == 5)  # Logical
print(x in [10, 20, 30])   # Membership
# Out:
# 15
# True
# True
# True

# %% [markdown]
# # 📝 Notes: Variables and Data Types in Python
# 🔹 What is a Variable?
#
# A variable is a name that refers to a value stored in memory or A variable is the name given to a memory location in a program.
# - Syntax:
# **Variable_name = value**
#
# Python is a fantastic language that automatically identifies the type of data for us.
# You don't need to declare the type — Python figures it out automatically.

# %%
name = "Amol"
age = 21
price = 99.99
is_student = True

# %%
print(name)
print(age)
print(price)
print(is_student)

# %% [markdown]
# # 🔢 Common Data Types :
#
# Primarily these are the following data types in Python:
# 1. Integers
# 2. Floating point numbers
# 3. Strings
# 4. Booleans
# 5. None

# %%
a = 71         # identifies a as class <int> 
b = 88.44      # identifies b as class <float> 
name= "harry"  # identifies name as class <str>

# %%
print(a,b,name)

# %% [markdown]
# **RULES FOR CHOOSING AN IDENTIFIER :**
#
# - A variable name can contain alphabets, digits, and underscores.
# - A variable name can only start with an alphabet and underscores.
# - A variable name can’t start with a digit.
# - No while space is allowed to be used inside a variable name.
#
# Examples of a few variable names are: harry, one8, seven, _seven etc.

# %% [markdown]
# # Declaring multiple variables in one line:

# %%
# Declaring multiple variables in one line
first_name, last_name, country, age, is_married = 'Bhushan', 'Mule', 'India', 21, True


print('First name:', first_name)
print('Last name: ', last_name)
print('Country: ', country)
print('Age: ', age)
print('Married: ', is_married)

# %% [markdown]
# # 🧪 Practice Examples :
# ✅ Example 1: Basic variable usage

# %%
username = "Bharti"
age = 22
is_logged_in = True

print("Name:", username)
print("Age:", age)
print("Logged In:", is_logged_in)

# %% [markdown]
# ✅ Example 2: Type conversion

# %%
a = "10"
b = 5
c = int(a) + b
print(c)  # Output: 15

# %% [markdown]
# ✅ Example 3: Swapping variables

# %%
x = 5
y = 10
x, y = y, x
print(x, y)  # Output: 10 5

# %%
# Variables in Python
first_name = 'Kunal'
last_name = 'Gaikwad'
country = 'India'
city = 'TELENGANA'
age = 21
is_married = False
skills = ['HTML', 'CSS', 'JS', 'React', 'Python']
person_info = {
    'firstname':'BHushan ', 
    'lastname':'Mule', 
    'country':'India',
    'city':'Beed'
    }

# %%
# Printing the values stored in the variables

print('First name:' , first_name)
print('First name length:', len(first_name))
print('Last name: ', last_name)
print('Last name length: ', len(last_name))
print('Country: ', country)
print('City: ', city)
print('Age: ', age)
print('Married: ', is_married)
print('Skills: ', skills)
print('Person information: ', person_info)

# %%
# Concatenating String - adding two variable 
first_name = "Kunal" 
last_name = "Gaikwad"
full_name = first_name + " " +last_name
print (full_name)

# %% [markdown]
# # 🧺 Lists :
# - Python lists are containers to store a set of values of any data type.
#
#   Ordered, changeable, allows duplicates.

# %%
fruits = ["apple", "banana", "cherry"]
fruits.append("orange")         # Add to end
fruits[0] = "mango"             # Change item
print(fruits[1])                # Access item
# Out:
# banana

# %%
l1 = [7,9,"harry"] 
l1[0] # 7 
l1[1] # 9 
#l1[70] # error 
l1[0:2] # [7,9]  #list slicing
# Out:
# [7, 9]

# %% [raw]
# List Methods:
#
# • l1.sort(): updates the list to [1,2,7,8,15,21]
# • l1.reverse(): updates the list to [15,21,2,7,8,1]
# • l1.append(8): adds 8 at the end of the list
# • l1.insert(3,8): This will add 8 at 3 index
# • l1.pop(2): Will delete element at index 2 and return its value.
# • l1.remove(21): Will remove 21 from the list.

# %%
#Consider the following list: 
l1 = [1,8,7,2,21,15]

# %%
l1.sort()
l1
# Out:
# [1, 2, 7, 8, 15, 21]

# %%
l1.reverse()
l1
# Out:
# [21, 15, 8, 7, 2, 1]

# %%
l1.append(8)
l1
# Out:
# [21, 15, 8, 7, 2, 1, 8]

# %%
l1.insert(3,8)
l1
# Out:
# [21, 15, 8, 8, 7, 2, 1, 8]

# %%
l1.pop(2)
l1
# Out:
# [21, 15, 8, 7, 2, 1, 8]

# %%
l1.remove(21)
l1
# Out:
# [15, 8, 7, 2, 1, 8]

# %%
#Store seven fruits in a list entered by the user
fruits = []
for i in range(7):
    fruit = input(f"Enter fruit {i+1}: ")
    fruits.append(fruit)

print("List of fruits:", fruits)
# Out:
# Enter fruit 1:  hjksd
# Enter fruit 2:  j
# Enter fruit 3:  d
# Enter fruit 4:  e
# Enter fruit 5:  e
# Enter fruit 6:  v
# Enter fruit 7:
# List of fruits: ['hjksd', 'j', 'd', 'e', 'e', 'v', '']

# %%
#Accept marks of 6 students and display them in a sorted manner
marks = []
for i in range(6):
    mark = int(input(f"Enter marks for student {i+1}: "))
    marks.append(mark)

marks.sort()
print("Sorted marks:", marks)
# Out:
# Enter marks for student 1:  50
# Enter marks for student 2:  56
# Enter marks for student 3:  45
# Enter marks for student 4:  83
# Enter marks for student 5:  56
# Enter marks for student 6:  48
# Sorted marks: [45, 48, 50, 56, 56, 83]

# %%
#Sum a list with 4 numbers
numbers = []
for i in range(4):
    num = float(input(f"Enter number {i+1}: "))
    numbers.append(num)

total = sum(numbers)
print("Sum of the list:", total)
# Out:
# Enter number 1:  45
# Enter number 2:  52
# Enter number 3:  9
# Enter number 4:  656
# Sum of the list: 762.0

# %% [markdown]
# # 🧱 Tuples :
# - A tuple is an immutable data type in python.
#
#   Ordered, unchangeable, allows duplicates.

# %%
colors = ("red", "green", "blue")
print(colors[0])
# Out:
# red

# %%
Tuple Methods:

• a.count (1): a count (1) will return number of times 1 occurs in a. 
• a.index (1) will return the index of first occurrence of 1 in a.

# %%
#Consider the following tuple.  
a = (1, 7, 2)

# %%
a.count (1)
# Out:
# 1

# %%
a.index (1)
# Out:
# 0

# %%
#Check that a tuple type cannot be changed in Python
my_tuple = (1, 2, 3)
try:
    my_tuple[0] = 10  # Attempt to change an element
except TypeError as e:
    print("Error:", e)
    print("This shows that tuples are immutable.")
# Out:
# Error: 'tuple' object does not support item assignment
# This shows that tuples are immutable.

# %%
#Count the number of zeros in the tuple a = (7, 0, 8, 0, 0, 9)
a = (7, 0, 8, 0, 0, 9)
zero_count = a.count(0)
print("Number of zeros in the tuple:", zero_count)
# Out:
# Number of zeros in the tuple: 3

# %% [markdown]
# # 🔥 Sets :
# - Set is a collection of non-repetitive elements.
#
#   Unordered, no duplicates.

# %%
unique_numbers = {1, 2, 3, 2}
print(unique_numbers)           # Output: {1, 2, 3}
unique_numbers.add(4)
# Out:
# {1, 2, 3}

# %%
s = set()           # no repetition allowed! 
s.add(1) 
s.add(2)            # or set ={1,2} 
s
# Out:
# {1, 2}

# %% [raw]
# PROPERTIES OF SETS
# 1. Sets are unordered => Element’s order doesn’t matter
# 2. Sets are unindexed => Cannot access elements by index
# 3. There is no way to change items in sets.
# 4. Sets cannot contain duplicate values.

# %% [markdown]
# **OPERATIONS ON SETS :**
# - len(s) : Returns 4, the length of the set
# - s.remove(8) : Updates the set s and removes 8 from s.
# - s.pop() : Removes an arbitrary element from the set and return the element
# removed.
# - s.clear() : empties the set s.
# - s.union({8,11}) : Returns a new set with all items from both sets. {1,8,2,3,11}.
# - s.intersection({8,11}) : Return a set which contains only item in both sets  {8}.

# %%
#Consider the following set: 
s = {1,8,2,3}

# %%
len(s)
# Out:
# 4

# %%
s.remove(8)
s
# Out:
# {1, 2, 3}

# %%
s.pop()
# Out:
# 1

# %%
s.union({8,11})
# Out:
# {2, 3, 8, 11}

# %%
s.intersection({8,11})
# Out:
# set()

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
#Input 8 numbers and display unique numbers
numbers = []
for i in range(8):
    num = int(input(f"Enter number {i+1}: "))
    numbers.append(num)

unique_numbers = set(numbers)
print("Unique numbers are:", unique_numbers)
# Out:
# Enter number 1:  3
# Enter number 2:  5
# Enter number 3:  9
# Enter number 4:  8
# Enter number 5:  6
# Enter number 6:  5
# Enter number 7:  8
# Enter number 8:  6
# Unique numbers are: {3, 5, 6, 8, 9}

# %%
#Can a set have 18 (int) and '18' (str)?
s = {18, '18'}
print(s)  # Output: {18, '18'}
# Out:
# {18, '18'}

# %%
#Length of set s after given operations
s = set()
s.add(20)      # Adds 20
s.add(20.0)    # 20.0 is equal to 20 in Python, so it's not added again
s.add('20')    # Different type, added

print(s)            # Output: {20, '20'}
print(len(s))       # Output: 2
# Out:
# {'20', 20}
# 2

# %%
# Out:
# <class 'dict'>

# %%
#Can you change list values inside a set like below?
s = {8, 7, 12, "Harry", [1, 2]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 2
#       1 #Can you change list values inside a set like below?
# ----> 2 s = {8, 7, 12, "Harry", [1, 2]}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # 📚 Dictionaries :
# - Dictionary is a collection of keys-value pairs.
#
#   Key-value pairs, unordered (in < Python 3.7).

# %%
person = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}
print(person["name"])
person["age"] = 31              # Update value
# Out:
# Alice

# %% [markdown]
# **PROPERTIES OF PYTHON DICTIONARIES:**
# 1. It is unordered.
# 2. It is mutable.
# 3. It is indexed.
# 4. Cannot contain duplicate keys.

# %% [markdown]
# **DICTIONARY METHODS :**
# - a.items() : Returns a list of (key,value)tuples.
# - a.keys() : Returns a list containing dictionary's keys.
# - a.update({"friends":}) : Updates the dictionary with supplied key-value pairs.
# - a.get("name") : Returns the value of the specified keys (and value is returned
#
# eg."harry" is returned here).

# %%
a={"name":"harry",
"from":"india",
"marks":[92,98,96]}

# %%
a
# Out:
# {'name': 'harry', 'from': 'india', 'marks': [92, 98, 96]}

# %%
a.items()
# Out:
# dict_items([('name', 'harry'), ('from', 'india'), ('marks', [92, 98, 96])])

# %%
a.keys()
# Out:
# dict_keys(['name', 'from', 'marks'])

# %%
a.update({"friends":'Bhushan'})

# %%
a
# Out:
# {'name': 'harry', 'from': 'india', 'marks': [92, 98, 96], 'friends': 'Bhushan'}

# %%
a.get("name")
# Out:
# 'harry'

# %%
# Hindi-English dictionary with lookup
hindi_dict = {
    "paani": "water",
    "aag": "fire",
    "dil": "heart",
    "kitab": "book"
}

word = input("Enter a Hindi word to look up its English meaning: ")
meaning = hindi_dict.get(word)

if meaning:
    print(f"The English meaning of '{word}' is: {meaning}")
else:
    print("Word not found in the dictionary.")
# Out:
# Enter a Hindi word to look up its English meaning:  paani
# The English meaning of 'paani' is: water

# %%
#What is the type of s = {}?
s = {}
print(type(s))  # Output: <class 'dict'> (It's a dictionary, not a set)
# Out:
# <class 'dict'>

# %%
#Create empty dictionary for 4 friends and their favorite languages
fav_lang = {}

for i in range(4):
    name = input(f"Enter name of friend {i+1}: ")
    language = input(f"Enter {name}'s favorite language: ")
    fav_lang[name] = language

print("Favorite languages:", fav_lang)
# Out:
# Enter name of friend 1:  marathi
# Enter marathi's favorite language:  la
# Enter name of friend 2:
# Enter 's favorite language:
# Enter name of friend 3:
# Enter 's favorite language:
# Enter name of friend 4:
# Enter 's favorite language:
# Favorite languages: {'marathi': 'la', '': ''}

# %% [markdown]
# # Type Casting :

# %% [markdown]
# It is basically a conversion of variables of a particular datatype into some other datatype, such that the conversion is valid.
#
# Type casting can be of two types :
# - Implicit Type Casting: In implicit type casting, the python compiler internally typecasts one variable into another type without the external action of the user.
# -  Explicit Type Casting: In explicit type casting, the user explicitly forces the compiler to convert a variable from one type to another.

# %%
a=str(31)    # integer to string conversion 
b=int("32")  # string to integer conversion 
c=float(32)  # integer to float conversion 
print(a,b,c)
# Out:
# 31 32 32.0

# %%
#Implicit Type casting
int_num = 100 
float_num = 1.01 
ans = int_num + float_num 
print(type(int_num)) 
print(type(float_num)) 
# ans is implicitly typecasted to float type for greater precision
print(type(ans))

# %%
int=10
float=10.6
ans= int + float
print(type(ans))

# %%
# Explicit Type casting
var=100
str(var)
# Out:
# '100'

# %%
a=150.15
str(a)
# Out:
# '150.15'

# %%
int(a)
# Out:
# 150

# %% [markdown]
# # INPUT () FUNCTION :
#
# This function allows the user to take input from the keyboard as a string.

# %%
A = input ("enter name")   # if a is "bhushan", the user entered bhushan
# Out:
# enter name bhushan

# %% [markdown]
# It is important to note that the output of input is always a string (even is a number is
# entered).

# %%
int(input())
# Out:
#  15
# 15

# %%
str(input())
# Out:
#  jknls
# 'jknls'

# %%
float(input())
# Out:
#  55.4
# 55.4

# %%
name= input("Enter your name: ")
age= int(input("Enter you age :"))
number= int(input("Enter your mobile number"))
# Out:
# Enter your name:  BHushan Mule
# Enter you age : 21
# Enter your mobile number 72491102868

# %%
print(name,age,number)
# Out:
# BHushan Mule 21 72491102868
