# %% [markdown]
# 1. What is the input() function in Python used for?

# %% [markdown]
# Ans: The input is built in function of python which is used for the taking input from the user.

# %%
#### Example:
a= input()
print(a)
# Out:
#  5
# 5

# %%
type(a)
# Out:
# str

# %% [markdown]
#  2. How can you accept an integer as input from the user using input()?

# %%
a= int(input("Enter the number:"))
print (a)
# Out:
# Enter the number: 545
# 545

# %%
type(a)
# Out:
# int

# %% [markdown]
# 3. How do you accept a float input from the user?

# %%
a=float(input("Enter the number:"))
print(a)
# Out:
# Enter the number: 45.45
# 45.45

# %% [markdown]
# 4. How can you take multiple space-separated values as input?

# %%
a= input("Enter a value").split()
print(a)
# Out:
# Enter a value 5656564
# ['5656564']

# %%
type(a)

# %% [markdown]
# 5. How do you check if a number entered by the user is positive, negative, or zero?

# %%
b=int(input("Enter a number:"))
if b>0:
    print("Number is positive")
elif b<0:
    print("Number is negative:")
else:
    print ("Number is zero")
# Out:
# Enter a number: 45
# Number is positive

# %% [markdown]
# 6. How do you convert user input to a list of integers?

# %%
a = [int(x) for x in input("Enter a numbers:")]
print(a)
# Out:
# Enter a numbers: 4546
# [4, 5, 4, 6]

# %% [markdown]
# 7. How do you accept a string input and print it in uppercase?

# %%
a =str(input("Enter string:"))
print(a.upper())
# Out:
# Enter string: kunal
# KUNAL

# %% [markdown]
# 8. Write a Python program that accepts a string and prints the number of vowels in it.

# %%
b = input("Enter a string: ") 
vowels = "aeiou" 
count = sum(1 for char in b if char.lower() in vowels) 
print("Number of vowels:", count)
# Out:
# Enter a string:  kunafjhgk
# Number of vowels: 2

# %% [markdown]
# 9. Write a program that takes a number as input and checks if it is even or odd.

# %%
a= int(input())
if a%2==0:
    print("even")
else:
    print ("odd")

# %% [markdown]
# 10. How would you check if a string is a palindrome using input()?

# %%
a=input("enter a string:")
if a==a[::-1]:
    print("palindrome")
else:
    print("no")
# Out:
# enter a string: kunallanuk
# palindrome

# %% [markdown]
# 11. Write a program that takes a number as input and prints its square.

# %%
num = int(input("enter a number:"))
a= num**2 
print (a)

# %% [markdown]
# 12. Write a program that asks for a number and prints whether it is divisible by 3.

# %%
a=int(input("Enter a number:"))
if a%3==0:
    print("Number is divisibale by 3")
else :
    print("num is not divisible by 3")
# Out:
# Enter a number: 9
# Number is divisibale by 3

# %% [markdown]
# 13. How would you check if a number is divisible by both 3 and 7?

# %%
a=int(input("Enter a number:"))
if a%3==0 and a%7==0:
    print("Number is divisibale by 3 and 7")
else :
    print("num is not divisible by 3 and 7")
# Out:
# Enter a number: 21
# Number is divisibale by 3 and 7

# %% [markdown]
# 14. How do you accept a list of comma-separated values as input?

# %%
a = input().split(",")
print(a)
# Out:
#  sevi,bhusan
# ['sevi', 'bhusan']

# %%
type(a)

# %% [markdown]
# 15. Write a Python program that takes two numbers as input and prints their product.

# %%
a=int(input())
b=int(input())
c= a*b
print(c)
# Out:
#  32
#  86
# 2752

# %% [markdown]
# 16. Write a program that checks if the input number is a prime number.

# %%
a=int(input())
if a>0:
    
    print("is a prime number")
else :
    print("not a prime number")
# Out:
#  1
# is a prime number

# %% [markdown]
# 17. How can you accept a boolean value (True/False) from the user?

# %%
b=input("enter true or false:").lower() == True
# Out:
# enter true or false: False

# %% [markdown]
# 18. Write a program that accepts a string and prints the reverse of that string.

# %%
str=input("Enter a string: ")
b =str[::-1]
print(b)
# Out:
# Enter a string:  kunal
# lanuk

# %% [markdown]
# 19. Write a program that asks for a user's name and age and prints a message.

# %%
a=input("Enter your name:")
b=int(input("Enter your age:"))
print("Hii",a ,"your age is ",b)
# Out:
# Enter your name: kunal
# Enter your age: 21
# Hii kunal your age is  21

# %% [markdown]
# 20. Write a program to calculate the factorial of a number using input().

# %%
num = int(input("Enter a number: ")) 
factorial = 1 
for i in range(1, num + 1): 
    factorial *= i 
print("Factorial:", factorial)
# Out:
# Enter a number:  5
# Factorial: 120

# %% [markdown]
#  21. How do you prevent a user from entering an empty string?

# %%
a=input().strip()
if not a:
    print("empty")
else :
    print("not")
# Out:
# empty

# %% [markdown]
# 22. Write a program to check if the entered number is a perfect square.

# %%
import math
a= int(input("enter num"))
if math.isqrt(a)**2==a:
    print("perfect")
else:
    print("not")
# Out:
# enter num 3
# not

# %% [markdown]
# 23. Write a program that asks for a year and determines if it's a leap year.

# %%
year=int(input("Enter year:"))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0): 
    print("Leap year")
else:
    print("not")
# Out:
# Enter year: 2027
# not

# %% [markdown]
# 24. How can you remove leading and trailing spaces from a string input?

# %%
a=input().strip()
# Out:
#  b h j

# %% [markdown]
# 25. How do you handle incorrect inputs when you expect an integer using input()?

# %%
try: 
    num = int(input("Enter a number: ")) 
except ValueError: 
    print("Invalid input! Please enter a valid integer.")
# Out:
# Enter a number:  vsdhbhds
# Invalid input! Please enter a valid integer.

# %% [markdown]
# 26. Write a program that accepts a string and counts the occurrence
# of a particular character.

# %%
a= (input("Enter the String"))
Count=a.count("k")
print(Count)
# Out:
# Enter the String kunalkkk
# 4

# %% [markdown]
# 27. How would you convert user input to lowercase using input()?

# %%
b= input("Enter the string :")
print(b.lower())
# Out:
# Enter the string : KUANL
# kuanl

# %% [markdown]
# 28. Write a program that accepts a number and prints whether it is a multiple of 10.

# %%
num = int(input("Enter the nummber :"))

if num%10==0:
    print("The num is multiple of 10")
else:
    print("The num is not multiple of 10")
# Out:
# Enter the nummber : 45
# The num is not multiple of 10

# %% [markdown]
# 29. How would you check if a string entered by the user contains only alphabets using
# input()?

# %%
c = input("Enter the string :")

if c.isalpha():
    print("String contains alphabets")
else:
    print("no alphabet")
# Out:
# Enter the string : sdsa
# String contains alphabets

# %% [markdown]
# 30. Write a program to count the number of words in a sentence entered by the user.

# %%
word= input()

print(len(word))
# Out:
#  cfcugdjknalk
# 12

# %% [markdown]
# 31. How would you accept a date input from the user in Python?

# %%
from datetime import datetime 
date_str = input("Enter a date (YYYY-MM-DD): ") 
date = datetime.strptime(date_str, "%Y-%m-%d") 
print("Entered date:", date)
# Out:
# Enter a date (YYYY-MM-DD):  2004-02-07
# Entered date: 2004-02-07 00:00:00

# %% [markdown]
# 32. Write a program that checks if the entered number is divisible by both 3 and 5.

# %%
num=int(input("Enter the number"))

if num%3==0 and num%5==0:
    print(num ,"is divisible by both")
else:
    print(num, "is not divisible by both")
# Out:
# Enter the number 18
# 18 is not divisible by both

# %% [markdown]
# 33. Write a program to swap the values of two variables using input().

# %%
a= int(input())
b=int(input())

a,b=b,a
print(f"SWwapped Num: a={a} , b={b}")
# Out:
#  120
#  145
# SWwapped Num: a=145 , b=120

# %% [markdown]
# 34. Write a program to take user input and print it without spaces between words.

# %%
a = input()
print(a.replace(" ", ""))
# Out:
#  kunal gaikwad
# kunalgaikwad

# %% [markdown]
# 35. How do you validate if an entered input is a valid email address?

# %%
import re
email = input("Enter email: ") 
if re.match(r"[^@]+@[^@]+\.[^@]+", email):
    print("Valid email") 
else: 
    print("Invalid email")
# Out:
# Enter email:  kunalgaikwad@gmail.com
# Valid email

# %% [markdown]
# 36. Write a program that accepts a number and prints its cube.

# %%
num= int(input("Enter the number: "))
print("Cube of num :",num**3)
# Out:
# Enter the number:  45
# Cube of num : 91125

# %% [markdown]
# 37. How would you accept and store multiple names from the user?

# %%
name=input("Enter the name :").split()
print("Names :",name)
# Out:
# Enter the name : Kunal BHushan Amol Manish
# Names : ['Kunal', 'BHushan', 'Amol', 'Manish']

# %% [markdown]
# 38. How would you extract numbers from a string entered by the user?

# %%
import re 
text = input("Enter a string: ") 
numbers = re.findall(r'\d+', text) 
print("Extracted numbers:", numbers)
# Out:
# Enter a string:  cfyvhjj48455dxcfvghbj
# Extracted numbers: ['48455']

# %% [markdown]
# 39. How do you find the maximum number from a list of integers entered by the user?

# %%
numbers = list(map(int, input("Enter numbers separated by spaces: ").split())) 
print("Maximum number:", max(numbers))
# Out:
# Enter numbers separated by spaces:  7 8 98 54 32
# Maximum number: 98

# %% [markdown]
# 40. How would you prompt the user for input until they enter a valid number?

# %%
while True:
    try:
        num = int(input("Enter a valid number: "))
        break
    except ValueError: 
        print("Invalid input, please enter a number.")
# Out:
# Enter a valid number:  sa
# Invalid input, please enter a number.
# Enter a valid number:  a
# Invalid input, please enter a number.
# Enter a valid number:  as
# Invalid input, please enter a number.
# Enter a valid number:  a45
# Invalid input, please enter a number.
# Enter a valid number:  5

# %% [markdown]
# 41. Write a program to check if the entered string has digits.

# %%
user_input = input("Enter a string: ") 
if any(char.isdigit() for char in user_input): 
    print("Contains digits") 
else: 
    print("No digits")
# Out:
# Enter a string:  aaaa5s5d6
# Contains digits

# %% [markdown]
# 42. Write a program to check if the entered string has only whitespace characters.

# %%
user_input = input("Enter a string: ") 
if user_input.isspace(): 
    print("Only whitespace") 
else: 
    print("Contains non-whitespace characters")
# Out:
# Enter a string:  ass
# Contains non-whitespace characters

# %% [markdown]
# 43. Write a program to find the sum of all digits in a string entered by the user.

# %%
text = input("Enter a string: ") 
digit_sum = sum(int(digit) for digit in text if digit.isdigit()) 
print("Sum of digits:", digit_sum)
# Out:
# Enter a string:  jhkbudh576dids54
# Sum of digits: 27

# %% [markdown]
# 44. Write a program that accepts a number and prints its absolute value.

# %%
num = int(input("Enter a number: ")) 

print("Absolute value:", abs(num))
# Out:
# Enter a number:  17
# Absolute value: 17

# %% [markdown]
# 45. How would you check if a string entered by the user contains any uppercase
# letters?

# %%
user_input = input("Enter a string: ") 
if any(char.isupper() for char in user_input): 
    print("Contains uppercase letters") 
else: 
    print("No uppercase letters")
# Out:
# Enter a string:  hhudsj
# No uppercase letters

# %% [markdown]
# 46. Write a program that converts Celsius to Fahrenheit.

# %%
celsius = float(input("Enter temperature in Celsius: ")) 
fahrenheit = (celsius * 9/5) + 32 
print(f"Temperature in Fahrenheit: {fahrenheit}")
# Out:
# Enter temperature in Celsius:  453
# Temperature in Fahrenheit: 847.4

# %% [markdown]
# 47. Write a program to find the average of a list of numbers entered by the user

# %%
numbers = list(map(int, input("Enter numbers separated by space: ").split())) 
print("Average:", sum(numbers) / len(numbers))
# Out:
# Enter numbers separated by space:  4 5 7 8 5
# Average: 5.8

# %% [markdown]
# 48. Write a program to count the number of consonants in a string entered by the
# user.

# %%
text = input("Enter a string: ") 
consonants = "bcdfghjklmnpqrstvwxyz" 
count = sum(1 for char in text.lower() if char in consonants) 
print("Number of consonants:", count)
# Out:
# Enter a string:  ddfgjghkjk
# Number of consonants: 10

# %% [markdown]
# 49. How do you check if a string entered by the user contains any punctuation?

# %%
import string 
text = input("Enter a string: ") 
if any(char in string.punctuation for char in text): 
    print("Contains punctuation") 
else: 
    print("No punctuation")
# Out:
# Enter a string:  dfhcvjb
# No punctuation

# %% [markdown]
# 50. Write a program that accepts a sentence and prints the longest word.

# %%
text = input("Enter a sentence: ") 
words = text.split() 
longest_word = max(words, key=len) 
print("Longest word:", longest_word)
# Out:
# Enter a sentence:  gysgsd hgyisy hhgshbsb ksks
# Longest word: hhgshbsb
