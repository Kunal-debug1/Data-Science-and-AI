# %% [markdown]
# # 🧵 Strings & String Methods in Python –

# %% [markdown]
# 📌 What is a String?
# - A string is a sequence of characters enclosed in single (' '), double (" "), or triple quotes (''' ''' or """ """).
#
# - Strings are immutable in Python (they cannot be changed after creation).

# %%
s1 = 'Hello'
s2 = "Python"
s3 = '''This is a
multi-line string'''

# %%
s1
# Out:
# 'Hello'

# %%
s2
# Out:
# 'Python'

# %%
s3
# Out:
# 'This is a\nmulti-line string'

# %%
a=10
b=30
c=a+b
print('Additinon of', a , 'and' , b , 'is=' , c)
# Out:
# Additinon of 10 and 30 is= 40

# %%
name="Kunal"
age =  21
live= "csn"

print("Hello! \nI am",name, "\nmy age is",age, "\ni live in", live)
# Out:
# Hello!
# I am Kunal
# my age is 21
# i live in csn

# %% [markdown]
# **print Format method**
#
# -first deside how the print statement should be
#
# -like:- The addition of 20 and 30 is = 50
#
# -then replace the variable position with curly brtacesm { }
#
# -then appply .format(val1,val2,....val-n methodm

# %%
num1=20 
num2=30 
add=num1+num2 
print('The addition of {} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of 20 and 30 is= 50

# %%
a=40
b=3
sub=a-b
print('The substraction of {} and{} is={}'.format(a,b,sub))
# Out:
# The substraction of 40 and3 is=37

# %%
name= "hemant"
c="IT vedant"
age=22
print('Hii im {} my age is {} i recently join the {} '.format(name,age,c))
# Out:
# Hii im hemant my age is 22 i recently join the IT vedant

# %%
num1=100 
num2=25 
num3=333 
num1=20 
num2=30 
avg=(num1+num2+num3)/3 # or we can use avg=round(num1+num2+num3)/3,2) 
avg1=round((num1+num2+num3)/3,2) 
# The avrage of num1,num2,num3 is = avg 
print('The avrage of {}, {}, and {} is= {} or {}'.format(num1,num2,num3, 
avg,avg1)) # here we can use round(avg,2) also
# Out:
# The avrage of 20, 30, and 333 is= 127.66666666666667 or 127.67

# %%
round(avg,2)
#round is used for removing the value after the "." 
#round (avg,3------we can get what we put
# Out:
# 127.67

# %% [markdown]
# 🔤 String Indexing & Slicing
# - Indexing: Access characters using position (starting from 0).
#
# - Slicing: Extract parts of strings using [start:end:step].

# %%
text = "Python"
print(text[0])      # P
print(text[-1])     # n
print(text[1:4])    # yth
print(text[::2])    # Pto
# Out:
# P
# n
# yth
# Pto

# %%
# Slicing
language = 'Pythonk'
first_three = language[0:3] # starts at zero index and up to 3 but not include 3
last_three = language[3:6]
print(last_three) # hon
# Out:
# hon

# %%
# Another way
last_three = language[-3:]
print(last_three)   # hon
last_three = language[3:]
print(last_three)   # hon
# Out:
# onk
# honk

# %%
name= "Hemant"

f_two=name[0:2]
l_two=name[2:6]

print(f_two)
print(l_two)
# Out:
# He
# mant

# %%
# Skipping character while splitting Python strings
language = 'Python'
pto = language[0:6:2] # 
print(pto) # pto
# Out:
# Pto

# %%
name= "Bhushanmule"
a= name[0:11:4]
print(a)
# Out:
# Bhu

# %%
name = "kunalgaikwad"
b= name[0:12:3]
print(b)
# Out:
# kaaw

# %%
#to reverse a string 
name= "hemant"
revers=name[::-1]
print(revers)
# Out:
# tnameh

# %% [markdown]
# **🛠️ Common String Methods**
# | Method              | Description                            | Example                     | Output            |
# | ------------------- | -------------------------------------- | --------------------------- | ----------------- |
# | `lower()`           | Converts to lowercase                  | `'HELLO'.lower()`           | `'hello'`         |
# | `upper()`           | Converts to uppercase                  | `'hello'.upper()`           | `'HELLO'`         |
# | `title()`           | Title case each word                   | `'hello world'.title()`     | `'Hello World'`   |
# | `strip()`           | Removes leading/trailing spaces        | `' hello '.strip()`         | `'hello'`         |
# | `replace(old, new)` | Replaces substring                     | `'apple'.replace('a','A')`  | `'Apple'`         |
# | `split()`           | Splits string into list                | `'a,b,c'.split(',')`        | `['a', 'b', 'c']` |
# | `join()`            | Joins list into string                 | `' '.join(['a', 'b'])`      | `'a b'`           |
# | `find()`            | Finds index of first occurrence        | `'hello'.find('l')`         | `2`               |
# | `count()`           | Counts occurrence of substring         | `'banana'.count('a')`       | `3`               |
# | `startswith()`      | Checks if string starts with substring | `'python'.startswith('py')` | `True`            |
# | `endswith()`        | Checks if string ends with substring   | `'code.py'.endswith('.py')` | `True`            |
# | `isalpha()`         | Checks if all characters are letters   | `'abc'.isalpha()`           | `True`            |
# | `isdigit()`         | Checks if all characters are digits    | `'1234'.isdigit()`          | `True`            |

# %%
# capitalize(): Converts the first character the string to Capital Letter
challenge = 'thirty days of python'
print(challenge.capitalize()) # 'Thirty days of python'
# Out:
# Thirty days of python

# %%
a= "hi, how are you? "
print(a.capitalize())
# Out:
# Hi, how are you?

# %%
# count(): returns occurrences of substring in string, count(substring, start=.., end=..)

challenge = 'thirty days of python'
print(challenge.count('y')) # 3
print(challenge.count('y', 7, 14)) # 1
print(challenge.count('th')) # 2`

# %%
b= "hi, how are you?"
print(a.count("?"))
print(a.count("h"))
# Out:
# 1
# 2

# %%
# endswith(): Checks if a string ends with a specified ending

challenge = 'thirty days of python'
print(challenge.endswith('on'))   # True
print(challenge.endswith('tion')) # False
# Out:
# True
# False

# %%
a="hi, how are you?"
print(a.endswith("ou"))
print(a.endswith("ou?"))
# Out:
# False
# True

# %%
# expandtabs(): Replaces tab character with spaces, default tab size is 8. It takes tab size argument\
challenge = 'thirty\tdays\tof\tpython'
print(challenge.expandtabs())   # 'thirty  days    of      python'
print(challenge.expandtabs(10)) # 'thirty    days      of        python'
# Out:
# thirty  days    of      python
# thirty    days      of        python

# %%
b = "hi\thow\tare\tyou"
print(b.expandtabs(10))
# Out:
# hi        how       are       you

# %%
# find(): Returns the index of first occurrence of substring

challenge = 'thirty days of python'
print(challenge.find('y'))  # 5
print(challenge.find('th')) # 0
# Out:
# 5
# 0

# %%
c= "hi, how are you?"
print(c.find("o"))
# Out:
# 5

# %%
# format()	formats string into nicer output    
first_name = 'Asabeneh'
last_name = 'Yetayeh'
job = 'teacher'
country = 'Finland'
sentence = 'I am {} {}. I am a {}. I live in {}.'.format(first_name, last_name, job, country)
print(sentence) # I am Asabeneh Yetayeh. I am a teacher. I live in Finland.
# Out:
# I am Asabeneh Yetayeh. I am a teacher. I live in Finland.

# %%
first_name = 'Bhushan'
last_name = 'Mule'
job = 'Treader'
country = 'India'
sentence = 'I am {} {}. I am a {}. I live in {}.'.format(first_name, last_name, job, country)

# %%
sentence
# Out:
# 'I am Bhushan Mule. I am a Treader. I live in India.'

# %%
radius = 10
pi = 3.14
area = pi # radius ## 2
result = 'The area of circle with {} is {}'.format(str(radius), str(area))
print(result) # The area of circle with 10 is 314.0
# Out:
# The area of circle with 10 is 3.14

# %%
# index(): Returns the index of substring
challenge = 'thirty days of python'
print(challenge.find('y'))  # 5
print(challenge.find('th')) # 0
# Out:
# 5
# 0

# %%
# isalnum(): Checks alphanumeric character

challenge = 'ThirtyDaysPython'
print(challenge.isalnum()) # True

challenge = '30DaysPython'
print(challenge.isalnum()) # True

challenge = 'thirty days of python'
print(challenge.isalnum()) # False

challenge = 'thirty days of python 2019'
print(challenge.isalnum()) # False
# Out:
# True
# True
# False
# False

# %%
# isalpha(): Checks if all characters are alphabets

challenge = 'thirty days of python'
print(challenge.isalpha()) # True
num = '123'
print(num.isalpha())      # False
# Out:
# False
# False

# %%
# isdecimal(): Checks Decimal Characters

challenge = 'thirty days of python'
print(challenge.find('y'))  # 5
print(challenge.find('th')) # 0
# Out:
# 5
# 0

# %%
# isdigit(): Checks Digit Characters

challenge = 'Thirty'
print(challenge.isdigit()) # False
challenge = '30'
print(challenge.isdigit())   # True
# Out:
# False
# True

# %%
# isdecimal():Checks decimal characters

num = '10'
print(num.isdecimal()) # True
num = '10.5'
print(num.isdecimal()) # False
# Out:
# True
# False

# %%
# isidentifier():Checks for valid identifier means it check if a string is a valid variable name

challenge = '30DaysOfPython'
print(challenge.isidentifier()) # False, because it starts with a number
challenge = 'thirty_days_of_python'
print(challenge.isidentifier()) # True
# Out:
# False
# True

# %%
# islower():Checks if all alphabets in a string are lowercase

challenge = 'thirty days of python'
print(challenge.islower()) # True
challenge = 'Thirty days of python'
print(challenge.islower()) # False
# Out:
# True
# False

# %%
# isupper(): returns if all characters are uppercase characters

challenge = 'thirty days of python'
print(challenge.isupper()) #  False
challenge = 'THIRTY DAYS OF PYTHON'
print(challenge.isupper()) # True
# Out:
# False
# True

# %%
# isnumeric():Checks numeric characters

num = '10'
print(num.isnumeric())      # True
print('ten'.isnumeric())    # False
# Out:
# True
# False

# %%
# join(): Returns a concatenated string

web_tech = ['HTML', 'CSS', 'JavaScript', 'React']
result = '#, '.join(web_tech)
print(result) # 'HTML# CSS# JavaScript# React'
# Out:
# HTML#, CSS#, JavaScript#, React

# %%
# strip(): Removes both leading and trailing characters

challenge = ' thirty days of python '
print(challenge.strip('y')) # 5
# Out:
#  thirty days of python

# %%
# replace(): Replaces substring inside

challenge = 'thirty days of python'
print(challenge.replace('python', 'coding')) # 'thirty days of coding'
# Out:
# thirty days of coding

# %%
# split():Splits String from Left

challenge = 'thirty days of python'
print(challenge.split()) # ['thirty', 'days', 'of', 'python']
# Out:
# ['thirty', 'days', 'of', 'python']

# %%
# title(): Returns a Title Cased String

challenge = 'thirty days of python'
print(challenge.title()) # Thirty Days Of Python
# Out:
# Thirty Days Of Python

# %%
# swapcase(): Checks if String Starts with the Specified String
  
challenge = 'thirty days of python'
print(challenge.swapcase())   # THIRTY DAYS OF PYTHON
challenge = 'Thirty Days Of Python'
print(challenge.swapcase())  # tHIRTY dAYS oF pYTHON
# Out:
# THIRTY DAYS OF PYTHON
# tHIRTY dAYS oF pYTHON

# %%
# startswith(): Checks if String Starts with the Specified String

challenge = 'thirty days of python'
print(challenge.startswith('thirty')) # True
challenge = '30 days of python'
print(challenge.startswith('thirty')) # False
# Out:
# True
# False

# %%
# Concatenating String - adding two variable 
first_name = "Kunal" 
last_name = "Gaikwad"
full_name = first_name + " " +last_name
print (full_name)
# Out:
# Kunal Gaikwad

# %%
# Checking length of a string using len() builtin function
print(len(first_name))  # 5
print(len(last_name))   # 7
print(len(first_name) > len(last_name)) # True
print(len(full_name)) # 13
# Out:
# 5
# 7
# False
# 13

# %% [markdown]
# # Functions & Built-in Functions
# 🔹 Part 1: Python Functions (User-defined Functions)
#
# ✅ What is a Function?
# A function is a block of reusable code that performs a specific task.
#
# ✅ Why Use Functions?
#
# Reusability
#
# Modularity
#
# Better readability
#
# Easier debugging
#
# ✅ Syntax of a Function:

# %%
def function_name(parameters):
    # code block
    return result  # optional

# %% [markdown]
# ✅ Example:

# %%
def greet(name):
    return f"Hello, {name}!"

print(greet("Alice"))
# Out:
# Hello, Alice!

# %%
# ✅ Function with No Parameters:python

def say_hello():
    print("Hello!")

# %%
#✅ Function with Default Parameter:

def greet(name="Guest"):
    print(f"Hello, {name}")

# %%
#✅ Function with Multiple Parameters:

def add(a, b):
    return a + b

# %% [markdown]
# ✅ Return Statement:
#
# return sends a result back to the caller and ends the function.

# %% [markdown]
# 🔹 Part 2: Python Built-in Functions
#
# Python comes with many built-in functions that you can use right away without importing any module.
#
# ✅ Common Built-in Functions:

# %%
print()	#Outputs to the console

# %%
len()	#Returns length of a list, string, etc.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 len()	#Returns length of a list, string, etc.
#
# TypeError: len() takes exactly one argument (0 given)

# %%
int(), float(), str()	#Type conversions
# Out:
# (0, 0.0, '')

# %%
type()	#Returns the type of an object
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 type()	#Returns the type of an object
#
# TypeError: type() takes 1 or 3 arguments

# %%
input()	#Takes input from user
# Out:
#  1
# '1'

# %%
sum()	#Sums elements of an iterable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 sum()	#Sums elements of an iterable
#
# TypeError: sum() takes at least 1 positional argument (0 given)

# %%
range()	#Generates a sequence of numbers
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 range()	#Generates a sequence of numbers
#
# TypeError: range expected at least 1 argument, got 0

# %%
max(), min()	#Returns largest/smallest value

# %%
sorted()	#Returns a sorted list

# %%
abs()	#Absolute value

# %%
round()	 #Rounds a number

# %%
enumerate()	 #Returns index and value in a loop

# %%
zip()	#Combines multiple iterables

# %%
map()	#Applies a function to all items

# %%
filter()	#Filters items using a function

# %%
#Examl\ples:
numbers = [3, 7, 2]
print(sum(numbers))  # Output: 12

print(type("hello"))  # Output: <class 'str'>

print(sorted([5, 1, 3]))  # Output: [1, 3, 5]
# Out:
# 12
# <class 'str'>
# [1, 3, 5]

# %% [markdown]
# 🔁 Summary
#
# - Define your own functions using def
#
# - Use built-in functions for common tasks
#
# - Know when to return a value vs just printing

# %% [markdown]
# 🔹 What are Exceptions?
#
# Exceptions are errors that occur during the execution of a program.
# When Python encounters an error, it stops the program and raises an exception.

# %% [markdown]
# | Exception           | Description                             |
# | ------------------- | --------------------------------------- |
# | `ZeroDivisionError` | Dividing by zero                        |
# | `TypeError`         | Wrong data type used                    |
# | `ValueError`        | Correct type but inappropriate value    |
# | `IndexError`        | Index out of range in a list or string  |
# | `KeyError`          | Accessing a non-existent dictionary key |
# | `FileNotFoundError` | File does not exist                     |
# | `NameError`         | Variable not defined                    |
# | `ImportError`       | Import failed                           |

# %% [raw]
# 🔹 Basic Try-Except Syntax
#
# try:
#     # Code that may raise an exception
# except SomeException:
#     # Code to run if the exception occurs

# %%
#✅ Example:

try:
    result = 10 / 0
except ZeroDivisionError:
    print("You can't divide by zero!")
# Out:
# You can't divide by zero!

# %%
#🔹 Handling Multiple Exceptions

try:
    x = int("abc")
except ValueError:
    print("That was not a valid number!")
except ZeroDivisionError:
    print("Can't divide by zero!")
# Out:
# That was not a valid number!

# %%
#🔹 Using else and finally

try:
    num = int(input("Enter a number: "))
except ValueError:
    print("Invalid input!")
else:
    print("Success, you entered:", num)
finally:

    print("This runs no matter what.")
# Out:
# Enter a number:  hfdjs
# Invalid input!
# This runs no matter what.

# %% [markdown]
# - else: runs if no exception occurs
#
# - finally: always runs, used for cleanup (e.g., closing files)

# %%
#🔹 Raising Exceptions Manually
#You can raise exceptions using raise:

def check_age(age):
    if age < 0:
        raise ValueError("Age can't be negative.")
    return age

# %%
#🔹 Custom Exceptions
#You can create your own exception classes:

class MyCustomError(Exception):
    pass

raise MyCustomError("Something went wrong.")
# Out:
# ---------------------------------------------------------------------------
# MyCustomError                             Traceback (most recent call last)
# Cell In[25], line 7
#       4 class MyCustomError(Exception):
#       5     pass
# ----> 7 raise MyCustomError("Something went wrong.")
#
# MyCustomError: Something went wrong.

# %% [markdown]
# 🔁 Summary
# - Use try-except to catch errors and prevent crashes
#
# - Use else and finally for cleaner control flow
#
# - You can raise or define your own exceptions as needed

# %% [markdown]
# 🔹 What Are Conditionals?
#
# Conditionals allow your code to make decisions and run different blocks of code based on certain conditions.

# %% [markdown]
# 🔹 The if Statement
#
# ✅ Syntax:

# %% [raw]
# if condition:
#     # code block

# %%
# Example
age = 18
if age >= 18:
    print("You are an adult.")
# Out:
# You are an adult.

# %% [markdown]
# 🔹 if-else Statement
#
# ✅ Syntax:

# %% [raw]
# if condition:
#     # true block
# else:
#     # false block

# %%
#Example:
x = 10
if x > 0:
    print("Positive")
else:
    print("Non-positive")
# Out:
# Positive

# %% [markdown]
# 🔹 if-elif-else Chain
#
# ✅ Syntax:

# %% [raw]
# if condition1:
#     # block1
# elif condition2:
#     # block2
# else:
#     # block3

# %%
#Example

score = 85
if score >= 90:
    print("A")
elif score >= 80:
    print("B")
else:
    print("C or lower")
# Out:
# B

# %% [markdown]
# 🔹 Comparison Operators
#
# | Operator | Description           |
# | -------- | --------------------- |
# | `==`     | Equal to              |
# | `!=`     | Not equal to          |
# | `>`      | Greater than          |
# | `<`      | Less than             |
# | `>=`     | Greater than or equal |
# | `<=`     | Less than or equal    |

# %% [markdown]
# 🔹 Logical Operators
#
# | Operator | Description       | Example            |
# | -------- | ----------------- | ------------------ |
# | `and`    | Both must be true | `x > 5 and x < 10` |
# | `or`     | At least one true | `x < 0 or x > 100` |
# | `not`    | Negates condition | `not is_raining`   |

# %% [markdown]
# 🔹 Nested if Statements:
#
# You can put an if inside another if:

# %%
num = 15
if num > 10:
    if num < 20:
        print("Between 10 and 20")
# Out:
# Between 10 and 20

# %% [markdown]
# 🔁 Summary
# - Use if, elif, and else to control logic
#
# - Use comparison and logical operators to test conditions
#
# - Nest if statements when needed, but avoid deep nesting for clarity
